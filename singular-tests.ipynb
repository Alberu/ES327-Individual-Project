# %% [markdown]
# Config

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque

import os
import numpy as np
import pandas as pd
import random

# %%
config = {
    # config for the neural network
    "nn": {
        "window": 50, # this is also the window, window size or entries used to predict the future price
        "nLayers": 5,
        "neurons": 256, # 256
        "nFeatures": 5,
        "dropout": 0.2,
        "lossFunc": "huber_loss", # "huber_loss" Huber looss is better to give outliers some weight but not too much, which can be good for predicting asset prices?
        "optimizer": "adam", # "adam"
        "layerType": LSTM, # could set it upt to be a list of the layers that need to be generated [LSTM LSTM] 2 hidden layers 
    },
    "data": {
        "ticker": "NVDA", # "TSLA" "AMZN" "AAPL" "NVDA" "AMD"
        "offset": pd.DateOffset(years = 3, months = 0, days = 0),
        "lookahead": 1,
        "validation": 0.1, # percentage of training data to be used as validation
        "testSize": 0.1, # to test on 0.04 or       0.3 for 3 years
        "scale": True,
        "scaler": preprocessing.MinMaxScaler(),
        "inputs": ['adjclose', 'volume', 'open', 'high', 'low'],
    },
    "training": {
        "batch_size": 64, # 64
        "num_epoch": 900, # 500
    }
}
# add one to the days ahead
config['data']['lookahead'] += 1
print(config['data']['lookahead'])
# DISPLAY AROUGH ESTIMATE OF HOW MANY DAYS WILL BE USED FOR EACH SECTION
damping = 0.9 # some extra damping for extra days that data isn't collected

offset = config["data"]["offset"]
ts1 = pd.Timestamp('2023-02-25')
ts2 = ts1 + offset
td = ts2 - ts1
days_offset = int(td.days/7*5*damping) # find out the roungh amount of days imported
print(f"{days_offset} Total days used will be roughly imported\n")
print(f"{days_offset* (1-config['data']['validation']-config['data']['testSize'])} Days used for training")
print(f"{days_offset*config['data']['validation']} Days used for validation")
print(f"{days_offset*config['data']['testSize']} Days used for testing")

from tensorflow.keras import models
from tensorflow.keras.layers import Dropout, LSTM, Dense


"""
HERE mean_absolute_error CAN BE REPLACED BY mse?
Also need to have a look at bidirectional network and how that works and so forth

"""
def generateModel(
    window,
    n_layers=2,
    neurons=256,
    n_features=5,
    dropout=0.3,
    loss="mean_absolute_error",
    optimizer="rmsprop",
    layerType=LSTM
    ):
    # generate a keras model to linearly group a stasck of layers
    model = models.Sequential()
    # repeat for each layer
    for layer in range(n_layers):
        # check for first layer
        if layer == 0:
            """NEED TO FIGURE OUT THE DIFFERENE BETWEEN THEESE TWO LINES OF CODE, INPUT SHAPE AND BATCH INPUT SHAPE"""
            model.add(LSTM(neurons, return_sequences=True, input_shape=(window, n_features)))
            # model.add(layerType(neurons, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        # check for final layer
        elif layer == n_layers - 1:
            model.add(layerType(neurons, return_sequences=False))
        # middle/hidden layers
        else:
            model.add(layerType(neurons, return_sequences=True))

        # add dropout after each layer
        """ this layer helps prevent over fitting
        The Dropout layer randomly sets input units to 0
        with a frequency of rate at each step during training time,
        which helps prevent overfitting. Inputs not set to 0 are scaled up by 1/(1 - rate)
        such that the sum over all inputs is unchanged."""
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    # compile the model once it has be compelted
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# Import yfinance package (NEED OT DOUBLE CHEKC IF THIS IS ACTUALLY A MODEL THAT CAN BE USED)

# import yfinance as yf # make sure to unisntall if this isn't used in the future
from yahoo_fin import stock_info
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn import preprocessing

from collections import deque

def getData(
    ticker,
    offset
    ):
    # setup the start date and end date
    startDate = (datetime.now() - offset).date()
    endDate = datetime.now().date()
    # Get the data
    stocks = stock_info.get_data(ticker, startDate, endDate)
    # display how many days of data are being used for this
    print(f"{ticker} data has been imported between {startDate} and the {endDate}, for a total of {len(stocks)} days of data")
    # print(f"Each day contains the prices for: {stocks.columns}")
    return stocks

def setupData(
    stocks, # data to be reshaped
    window = 50, # the number of days used to predic the next value (window size or lookback perdiod)
    predAhead = 10, # the number of days ahead that you are tyring to predict
    validationSize = 0.1, # amount of data out of the training data to be used as validation
    testSize = 0.2, # the amount of data that will be  used for testing e.g. 0.2 -> 20%
    scale = True, # minmaxscaler
    scaler = preprocessing.MinMaxScaler(), # the scaler to be used
    inputs = ['adjclose', 'volume', 'open', 'high', 'low']
    ):
    # Setup a dictionary to store all the data
    data = {}
    # copy the data frame
    data["raw"] = stocks.copy()

    """This is something that really needs to be fixed in the future"""
    # I HAVE TO COPY THE STOCKS SO THAT THE ORIGINAL ONES AREN'T RETURNED? WHAT IS THIS ABOUT
    stocks = stocks.copy()
    



    # should we scale down between 0 and 1? It can make analysis easier
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in inputs:
            # scale the columns
            stocks[column] = scaler.fit_transform(np.expand_dims(stocks[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        data["column_scaler"] = column_scaler

    # create input a variable with x and y
    x = []
    y = []
    ydates = []
    for i in range(len(stocks)-window-predAhead+1):
        x.append(np.array(stocks[inputs].values[i:i+window]))
        y.append(stocks["adjclose"].values[i+window+predAhead-1])
        ydates.append(stocks.index[i+window+1])
    # convert into numpy arrays
    x = np.array(x)
    y = np.array(y)

    # store x and y into the data dictionary
    data["x"] = x
    data["y"] = y
    data["ydates"] =  ydates

    # split the dataset into training & testing sets by date
    # make sure to convert to an integer so that it can be used for indexing
    trainSamples = int((1 - testSize - validationSize) * len(x))
    valSamples = int(validationSize * len(x))
    data["xtrain"] = x[:trainSamples]
    data["ytrain"] = y[:trainSamples]

    data["xval"] = x[trainSamples:trainSamples+valSamples]
    data["yval"] = y[trainSamples:trainSamples+valSamples]

    data["xtest"]  = x[trainSamples+valSamples:]
    data["ytest"]  = y[trainSamples+valSamples:]
    
    data["trainDates"] = ydates[:trainSamples]
    data["valDates"] = ydates[trainSamples:trainSamples+valSamples]
    data["testDates"] = ydates[trainSamples+valSamples:]

    return data

# create a new model to be trained
model = generateModel(
    config["nn"]["window"],
    config["nn"]["nLayers"],
    config["nn"]["neurons"],
    n_features= config["nn"]["nFeatures"],
    dropout= config["nn"]["dropout"],
    loss= config["nn"]["lossFunc"],
    optimizer= config["nn"]["optimizer"],
    layerType= config["nn"]["layerType"]
    )
model.summary()
# Out:
# 2
# 2113 Total days used will be roughly imported
#
# 1690.4 Days used for training
# 211.3 Days used for validation
# 211.3 Days used for testing
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 20, 256)           268288
#
#  dropout_8 (Dropout)         (None, 20, 256)           0
#
#  lstm_9 (LSTM)               (None, 256)               525312
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 793,857
# Trainable params: 793,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Data

# %%
# download data form yt
stocks = getData(config["data"]["ticker"], config["data"]["offset"])


# process the data
config["data"]["scale"] = True
data = setupData(stocks, config["nn"]["window"], config["data"]["lookahead"], config["data"]["validation"], config["data"]["testSize"], config["data"]["scale"], config["data"]["scaler"], config["data"]["inputs"])
data.keys()

import matplotlib.pyplot as plt

lines = 100
fig = plt.figure(figsize=(25, 7), dpi=80)
# plot all the different lines
plt.plot(data["ydates"], data["y"])

step = round(len(data["raw"]["adjclose"].keys())/lines)
plt.xticks(data["ydates"][::step], rotation='vertical') 
# Plot the grid lines
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
scaled = lambda x: "Scaled " if x == True else ""
plt.title(f"{scaled(config['data']['scale'])}Adjusted Closing Price of {config['data']['ticker']}", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel(f"{scaled(config['data']['scale'])}Adjusted Closing Price", fontsize=14)
plt.xlabel("Date", fontsize=14)
plt.legend("Data Downloaded".split(","))
# show the plot
plt.show()

plots = "trainDates ytrain,valDates yval,testDates ytest"
lines = 100
fig = plt.figure(figsize=(25, 7), dpi=80)
# plot all the different lines
for plot in plots.split(","):
    x, y = plot.split()
    plt.plot(data[f"{x}"], data[f"{y}"])
step = round(len(data["raw"]["adjclose"].keys())/lines)
plt.xticks(data["ydates"][::step], rotation='vertical') 
# Plot the grid lines
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
scaled = lambda x: "Scaled " if x == True else ""
plt.title(f"{scaled(config['data']['scale'])}Adjusted Closing Price of {config['data']['ticker']} split into training, validation and testing data", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel(f"{scaled(config['data']['scale'])}Adjusted Closing Price", fontsize=14)
plt.xlabel("Date", fontsize=14)
plt.legend("Training Data,Validation Data,Testing Data".split(","))
# show the plot
plt.show()
# Out:
# TSLA data has been imported between 2014-03-14 and the 2023-03-14, for a total of 2265 days of data

# %% [markdown]
# Training

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_name = "trials"

# create a new model to be trained
model = generateModel(
    config["nn"]["window"],
    config["nn"]["nLayers"],
    config["nn"]["neurons"],
    n_features= config["nn"]["nFeatures"],
    dropout= config["nn"]["dropout"],
    loss= config["nn"]["lossFunc"],
    optimizer= config["nn"]["optimizer"],
    layerType= config["nn"]["layerType"]
    )
model.summary()
# checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
# tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

# Train the model by using the funciton fit
history = model.fit(data["xtrain"], data["ytrain"],
                    batch_size=config["training"]["batch_size"],
                    epochs=config["training"]["num_epoch"],
                    validation_data=(data["xval"], data["yval"]),
                    callbacks= EarlyStopping(monitor='val_loss', patience= 50),
                    verbose=1) # should be able to chance verbose to 100 to display every 100 but doesn't seem to work
                    # callbacks=[checkpointer, tensorboard],
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 20, 256)           268288
#
#  dropout_10 (Dropout)        (None, 20, 256)           0
#
#  lstm_11 (LSTM)              (None, 256)               525312
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 793,857
# Trainable params: 793,857
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/900
# 2023-03-14 12:28:55.301862: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:55.600752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:55.749653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:55.955492: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:56.108674: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 29/29 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0323
# 2023-03-14 12:28:57.612194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:57.695158: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:28:57.762912: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 29/29 [==============================] - 5s 62ms/step - loss: 0.0020 - mean_absolute_error: 0.0323 - val_loss: 0.0017 - val_mean_absolute_error: 0.0419
# Epoch 2/900
# 29/29 [==============================] - 1s 27ms/step - loss: 2.3218e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0027 - val_mean_absolute_error: 0.0506
# Epoch 3/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.3954e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0022 - val_mean_absolute_error: 0.0456
# Epoch 4/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.4491e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0019 - val_mean_absolute_error: 0.0412
# Epoch 5/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.6003e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0399
# Epoch 6/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.3000e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0016 - val_mean_absolute_error: 0.0387
# Epoch 7/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.2202e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0025 - val_mean_absolute_error: 0.0507
# Epoch 8/900
# 29/29 [==============================] - 1s 24ms/step - loss: 1.3343e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0015 - val_mean_absolute_error: 0.0381
# Epoch 9/900
# 29/29 [==============================] - 1s 24ms/step - loss: 1.4055e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0023 - val_mean_absolute_error: 0.0483
# Epoch 10/900
# 29/29 [==============================] - 1s 24ms/step - loss: 1.2951e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0014 - val_mean_absolute_error: 0.0387
# Epoch 11/900
# 29/29 [==============================] - 1s 24ms/step - loss: 1.2752e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0015 - val_mean_absolute_error: 0.0376
# Epoch 12/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.4321e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0019 - val_mean_absolute_error: 0.0437
# Epoch 13/900
# 29/29 [==============================] - 1s 24ms/step - loss: 1.0436e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0026 - val_mean_absolute_error: 0.0539
# Epoch 14/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.0206e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0086 - val_mean_absolute_error: 0.1191
# Epoch 15/900
# 29/29 [==============================] - 1s 25ms/step - loss: 5.0759e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0021 - val_mean_absolute_error: 0.0565
# Epoch 16/900
# 29/29 [==============================] - 1s 26ms/step - loss: 3.2395e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0022 - val_mean_absolute_error: 0.0467
# Epoch 17/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.2770e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0019 - val_mean_absolute_error: 0.0429
# Epoch 18/900
# 29/29 [==============================] - 1s 28ms/step - loss: 1.1715e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0018 - val_mean_absolute_error: 0.0420
# Epoch 19/900
# 29/29 [==============================] - 1s 27ms/step - loss: 9.5806e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0012 - val_mean_absolute_error: 0.0363
# Epoch 20/900
# 29/29 [==============================] - 1s 28ms/step - loss: 1.1963e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0042 - val_mean_absolute_error: 0.0762
# Epoch 21/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.2682e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0016 - val_mean_absolute_error: 0.0394
# Epoch 22/900
# 29/29 [==============================] - 1s 28ms/step - loss: 1.0527e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0015 - val_mean_absolute_error: 0.0377
# Epoch 23/900
# 29/29 [==============================] - 1s 29ms/step - loss: 1.1408e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0356
# Epoch 24/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.1820e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0012 - val_mean_absolute_error: 0.0369
# Epoch 25/900
# 29/29 [==============================] - 1s 29ms/step - loss: 1.9334e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0014 - val_mean_absolute_error: 0.0367
# Epoch 26/900
# 29/29 [==============================] - 1s 28ms/step - loss: 1.0892e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0011 - val_mean_absolute_error: 0.0345
# Epoch 27/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.0795e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0015 - val_mean_absolute_error: 0.0379
# Epoch 28/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.4289e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0029 - val_mean_absolute_error: 0.0610
# Epoch 29/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.0621e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0012 - val_mean_absolute_error: 0.0340
# Epoch 30/900
# 29/29 [==============================] - 1s 27ms/step - loss: 8.6771e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0015 - val_mean_absolute_error: 0.0392
# Epoch 31/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.5052e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0031 - val_mean_absolute_error: 0.0628
# Epoch 32/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.8662e-05 - mean_absolute_error: 0.0072 - val_loss: 0.0011 - val_mean_absolute_error: 0.0344
# Epoch 33/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.2089e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0015 - val_mean_absolute_error: 0.0389
# Epoch 34/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.9381e-05 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0334
# Epoch 35/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.3873e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0025 - val_mean_absolute_error: 0.0560
# Epoch 36/900
# 29/29 [==============================] - 1s 28ms/step - loss: 9.4695e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0019 - val_mean_absolute_error: 0.0465
# Epoch 37/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.6233e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0026 - val_mean_absolute_error: 0.0575
# Epoch 38/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.3247e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0011 - val_mean_absolute_error: 0.0327
# Epoch 39/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.5866e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0017 - val_mean_absolute_error: 0.0438
# Epoch 40/900
# 29/29 [==============================] - 1s 24ms/step - loss: 8.5383e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0012 - val_mean_absolute_error: 0.0353
# Epoch 41/900
# 29/29 [==============================] - 1s 24ms/step - loss: 8.8461e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0010 - val_mean_absolute_error: 0.0328
# Epoch 42/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.1752e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0015 - val_mean_absolute_error: 0.0389
# Epoch 43/900
# 29/29 [==============================] - 1s 24ms/step - loss: 8.9996e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0028 - val_mean_absolute_error: 0.0606
# Epoch 44/900
# 29/29 [==============================] - 1s 24ms/step - loss: 9.3415e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0011 - val_mean_absolute_error: 0.0367
# Epoch 45/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.5920e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0012 - val_mean_absolute_error: 0.0347
# Epoch 46/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.1545e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0015 - val_mean_absolute_error: 0.0393
# Epoch 47/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.1016e-04 - mean_absolute_error: 0.0072 - val_loss: 9.9440e-04 - val_mean_absolute_error: 0.0334
# Epoch 48/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.0286e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0017 - val_mean_absolute_error: 0.0430
# Epoch 49/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.0905e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0022 - val_mean_absolute_error: 0.0512
# Epoch 50/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.8382e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0043 - val_mean_absolute_error: 0.0796
# Epoch 51/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.9232e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0031 - val_mean_absolute_error: 0.0646
# Epoch 52/900
# 29/29 [==============================] - 1s 28ms/step - loss: 9.9736e-05 - mean_absolute_error: 0.0081 - val_loss: 0.0013 - val_mean_absolute_error: 0.0359
# Epoch 53/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.6836e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0015 - val_mean_absolute_error: 0.0397
# Epoch 54/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.6767e-05 - mean_absolute_error: 0.0065 - val_loss: 0.0014 - val_mean_absolute_error: 0.0374
# Epoch 55/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.7510e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0020 - val_mean_absolute_error: 0.0480
# Epoch 56/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.0177e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0012 - val_mean_absolute_error: 0.0351
# Epoch 57/900
# 29/29 [==============================] - 1s 27ms/step - loss: 9.2697e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0016 - val_mean_absolute_error: 0.0414
# Epoch 58/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.1498e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0020 - val_mean_absolute_error: 0.0489
# Epoch 59/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.0273e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0017 - val_mean_absolute_error: 0.0437
# Epoch 60/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.0704e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0034 - val_mean_absolute_error: 0.0695
# Epoch 61/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.0028e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0011 - val_mean_absolute_error: 0.0328
# Epoch 62/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.4941e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0025 - val_mean_absolute_error: 0.0561
# Epoch 63/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.8826e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0014 - val_mean_absolute_error: 0.0390
# Epoch 64/900
# 29/29 [==============================] - 1s 30ms/step - loss: 9.4694e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0010 - val_mean_absolute_error: 0.0317
# Epoch 65/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.2916e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0029 - val_mean_absolute_error: 0.0624
# Epoch 66/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.6349e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0024 - val_mean_absolute_error: 0.0544
# Epoch 67/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.2246e-05 - mean_absolute_error: 0.0073 - val_loss: 9.6316e-04 - val_mean_absolute_error: 0.0314
# Epoch 68/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.4479e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0035 - val_mean_absolute_error: 0.0695
# Epoch 69/900
# 29/29 [==============================] - 1s 30ms/step - loss: 9.6812e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0040 - val_mean_absolute_error: 0.0761
# Epoch 70/900
# 29/29 [==============================] - 1s 27ms/step - loss: 1.2933e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0014 - val_mean_absolute_error: 0.0386
# Epoch 71/900
# 29/29 [==============================] - 1s 34ms/step - loss: 9.9032e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0030 - val_mean_absolute_error: 0.0635
# Epoch 72/900
# 29/29 [==============================] - 1s 31ms/step - loss: 8.5729e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0022 - val_mean_absolute_error: 0.0518
# Epoch 73/900
# 29/29 [==============================] - 1s 31ms/step - loss: 8.4639e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0017 - val_mean_absolute_error: 0.0433
# Epoch 74/900
# 29/29 [==============================] - 1s 31ms/step - loss: 8.2960e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0016 - val_mean_absolute_error: 0.0414
# Epoch 75/900
# 29/29 [==============================] - 1s 35ms/step - loss: 7.4913e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0017 - val_mean_absolute_error: 0.0434
# Epoch 76/900
# 29/29 [==============================] - 1s 33ms/step - loss: 7.5737e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0011 - val_mean_absolute_error: 0.0328
# Epoch 77/900
# 29/29 [==============================] - 1s 29ms/step - loss: 7.4445e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0027 - val_mean_absolute_error: 0.0595
# Epoch 78/900
# 29/29 [==============================] - 1s 28ms/step - loss: 9.2124e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0015 - val_mean_absolute_error: 0.0404
# Epoch 79/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.7030e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0026 - val_mean_absolute_error: 0.0584
# Epoch 80/900
# 29/29 [==============================] - 1s 29ms/step - loss: 7.2211e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0018 - val_mean_absolute_error: 0.0453
# Epoch 81/900
# 29/29 [==============================] - 1s 40ms/step - loss: 7.2299e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0029 - val_mean_absolute_error: 0.0626
# Epoch 82/900
# 29/29 [==============================] - 1s 28ms/step - loss: 7.7207e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0021 - val_mean_absolute_error: 0.0507
# Epoch 83/900
# 29/29 [==============================] - 1s 29ms/step - loss: 9.2119e-05 - mean_absolute_error: 0.0066 - val_loss: 8.8498e-04 - val_mean_absolute_error: 0.0317
# Epoch 84/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.8480e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0017 - val_mean_absolute_error: 0.0431
# Epoch 85/900
# 29/29 [==============================] - 1s 27ms/step - loss: 8.2481e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0016 - val_mean_absolute_error: 0.0418
# Epoch 86/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.3232e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0023 - val_mean_absolute_error: 0.0534
# Epoch 87/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.7239e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0014 - val_mean_absolute_error: 0.0392
# Epoch 88/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.3048e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0028 - val_mean_absolute_error: 0.0613
# Epoch 89/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.8206e-05 - mean_absolute_error: 0.0058 - val_loss: 9.9530e-04 - val_mean_absolute_error: 0.0314
# Epoch 90/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.8689e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0019 - val_mean_absolute_error: 0.0476
# Epoch 91/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.0469e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0016 - val_mean_absolute_error: 0.0413
# Epoch 92/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.1552e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0013 - val_mean_absolute_error: 0.0364
# Epoch 93/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.7917e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0020 - val_mean_absolute_error: 0.0496
# Epoch 94/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.2452e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0018 - val_mean_absolute_error: 0.0463
# Epoch 95/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.2108e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0334
# Epoch 96/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.0807e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0021 - val_mean_absolute_error: 0.0503
# Epoch 97/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5908e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0014 - val_mean_absolute_error: 0.0383
# Epoch 98/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.6080e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0029 - val_mean_absolute_error: 0.0624
# Epoch 99/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.5893e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0014 - val_mean_absolute_error: 0.0388
# Epoch 100/900
# 29/29 [==============================] - 1s 29ms/step - loss: 7.5098e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0032 - val_mean_absolute_error: 0.0678
# Epoch 101/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.5390e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0011 - val_mean_absolute_error: 0.0332
# Epoch 102/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.3687e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0014 - val_mean_absolute_error: 0.0388
# Epoch 103/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.0125e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0024 - val_mean_absolute_error: 0.0559
# Epoch 104/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.8003e-05 - mean_absolute_error: 0.0051 - val_loss: 8.8691e-04 - val_mean_absolute_error: 0.0304
# Epoch 105/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.0591e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0016 - val_mean_absolute_error: 0.0415
# Epoch 106/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.7639e-05 - mean_absolute_error: 0.0065 - val_loss: 9.9115e-04 - val_mean_absolute_error: 0.0313
# Epoch 107/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.4738e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0020 - val_mean_absolute_error: 0.0490
# Epoch 108/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.7315e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0030 - val_mean_absolute_error: 0.0639
# Epoch 109/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.0387e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0023 - val_mean_absolute_error: 0.0547
# Epoch 110/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.9887e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0017 - val_mean_absolute_error: 0.0439
# Epoch 111/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.1801e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0026 - val_mean_absolute_error: 0.0583
# Epoch 112/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.6209e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0031 - val_mean_absolute_error: 0.0657
# Epoch 113/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.0483e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0011 - val_mean_absolute_error: 0.0332
# Epoch 114/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5842e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0077 - val_mean_absolute_error: 0.1139
# Epoch 115/900
# 29/29 [==============================] - 1s 25ms/step - loss: 2.5827e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0025 - val_mean_absolute_error: 0.0554
# Epoch 116/900
# 29/29 [==============================] - 1s 25ms/step - loss: 9.3586e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0023 - val_mean_absolute_error: 0.0530
# Epoch 117/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.4207e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0018 - val_mean_absolute_error: 0.0452
# Epoch 118/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.8995e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0015 - val_mean_absolute_error: 0.0392
# Epoch 119/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.0111e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0014 - val_mean_absolute_error: 0.0382
# Epoch 120/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.2566e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0027 - val_mean_absolute_error: 0.0593
# Epoch 121/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5604e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0017 - val_mean_absolute_error: 0.0438
# Epoch 122/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.8174e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0027 - val_mean_absolute_error: 0.0605
# Epoch 123/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.8992e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0017 - val_mean_absolute_error: 0.0437
# Epoch 124/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.1823e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0013 - val_mean_absolute_error: 0.0357
# Epoch 125/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5144e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0031 - val_mean_absolute_error: 0.0657
# Epoch 126/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.7568e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0023 - val_mean_absolute_error: 0.0541
# Epoch 127/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.3378e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0012 - val_mean_absolute_error: 0.0348
# Epoch 128/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.9687e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0026 - val_mean_absolute_error: 0.0582
# Epoch 129/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.4239e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0036 - val_mean_absolute_error: 0.0721
# Epoch 130/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.4237e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0017 - val_mean_absolute_error: 0.0424
# Epoch 131/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5554e-05 - mean_absolute_error: 0.0055 - val_loss: 8.6811e-04 - val_mean_absolute_error: 0.0324
# Epoch 132/900
# 29/29 [==============================] - 1s 25ms/step - loss: 2.4307e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0048 - val_mean_absolute_error: 0.0865
# Epoch 133/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.2460e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0026 - val_mean_absolute_error: 0.0578
# Epoch 134/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.6272e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0020 - val_mean_absolute_error: 0.0488
# Epoch 135/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.2551e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0011 - val_mean_absolute_error: 0.0392
# Epoch 136/900
# 29/29 [==============================] - 1s 26ms/step - loss: 1.7336e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0052 - val_mean_absolute_error: 0.0893
# Epoch 137/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.4415e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0053 - val_mean_absolute_error: 0.0898
# Epoch 138/900
# 29/29 [==============================] - 1s 25ms/step - loss: 1.1318e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0028 - val_mean_absolute_error: 0.0589
# Epoch 139/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.8802e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0030 - val_mean_absolute_error: 0.0634
# Epoch 140/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.6473e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0026 - val_mean_absolute_error: 0.0579
# Epoch 141/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.1865e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0021 - val_mean_absolute_error: 0.0499
# Epoch 142/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.3932e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0023 - val_mean_absolute_error: 0.0525
# Epoch 143/900
# 29/29 [==============================] - 1s 26ms/step - loss: 9.5123e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0018 - val_mean_absolute_error: 0.0450
# Epoch 144/900
# 29/29 [==============================] - 1s 27ms/step - loss: 8.6932e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0016 - val_mean_absolute_error: 0.0413
# Epoch 145/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.7656e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0018 - val_mean_absolute_error: 0.0440
# Epoch 146/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.6738e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0012 - val_mean_absolute_error: 0.0339
# Epoch 147/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.0119e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0033 - val_mean_absolute_error: 0.0668
# Epoch 148/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.5635e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0011 - val_mean_absolute_error: 0.0334
# Epoch 149/900
# 29/29 [==============================] - 1s 25ms/step - loss: 7.6551e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0011 - val_mean_absolute_error: 0.0325
# Epoch 150/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.0249e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0016 - val_mean_absolute_error: 0.0406
# Epoch 151/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.6520e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0015 - val_mean_absolute_error: 0.0394
# Epoch 152/900
# 29/29 [==============================] - 1s 28ms/step - loss: 6.9692e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0017 - val_mean_absolute_error: 0.0440
# Epoch 153/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.7754e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0019 - val_mean_absolute_error: 0.0467
# Epoch 154/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.2300e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0019 - val_mean_absolute_error: 0.0472
# Epoch 155/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.4324e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0019 - val_mean_absolute_error: 0.0476
# Epoch 156/900
# 29/29 [==============================] - 1s 28ms/step - loss: 6.5613e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0024 - val_mean_absolute_error: 0.0550
# Epoch 157/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.2988e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0018 - val_mean_absolute_error: 0.0458
# Epoch 158/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.8848e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0024 - val_mean_absolute_error: 0.0556
# Epoch 159/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.3361e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0018 - val_mean_absolute_error: 0.0455
# Epoch 160/900
# 29/29 [==============================] - 1s 29ms/step - loss: 6.9215e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0013 - val_mean_absolute_error: 0.0354
# Epoch 161/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.3757e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0021 - val_mean_absolute_error: 0.0503
# Epoch 162/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.8310e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0025 - val_mean_absolute_error: 0.0569
# Epoch 163/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.7066e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0027 - val_mean_absolute_error: 0.0595
# Epoch 164/900
# 29/29 [==============================] - 1s 27ms/step - loss: 9.1489e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0033 - val_mean_absolute_error: 0.0677
# Epoch 165/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.6645e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0010 - val_mean_absolute_error: 0.0317
# Epoch 166/900
# 29/29 [==============================] - 1s 29ms/step - loss: 7.3124e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0016 - val_mean_absolute_error: 0.0420
# Epoch 167/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.7849e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0037 - val_mean_absolute_error: 0.0739
# Epoch 168/900
# 29/29 [==============================] - 1s 27ms/step - loss: 8.8700e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0039 - val_mean_absolute_error: 0.0754
# Epoch 169/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.1290e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0015 - val_mean_absolute_error: 0.0399
# Epoch 170/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.6844e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0029 - val_mean_absolute_error: 0.0623
# Epoch 171/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.5212e-05 - mean_absolute_error: 0.0049 - val_loss: 0.0016 - val_mean_absolute_error: 0.0414
# Epoch 172/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.2098e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0020 - val_mean_absolute_error: 0.0484
# Epoch 173/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.6088e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0034 - val_mean_absolute_error: 0.0692
# Epoch 174/900
# 29/29 [==============================] - 1s 25ms/step - loss: 8.6315e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0019 - val_mean_absolute_error: 0.0461
# Epoch 175/900
# 29/29 [==============================] - 1s 27ms/step - loss: 7.7602e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0039 - val_mean_absolute_error: 0.0756
# Epoch 176/900
# 29/29 [==============================] - 1s 26ms/step - loss: 8.3124e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0025 - val_mean_absolute_error: 0.0565
# Epoch 177/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.6981e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0029 - val_mean_absolute_error: 0.0628
# Epoch 178/900
# 29/29 [==============================] - 1s 25ms/step - loss: 6.6719e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0021 - val_mean_absolute_error: 0.0505
# Epoch 179/900
# 29/29 [==============================] - 1s 26ms/step - loss: 6.3000e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0011 - val_mean_absolute_error: 0.0333
# Epoch 180/900
# 29/29 [==============================] - 1s 26ms/step - loss: 7.4522e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0019 - val_mean_absolute_error: 0.0466
# Epoch 181/900
# 29/29 [==============================] - 1s 27ms/step - loss: 6.5759e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0017 - val_mean_absolute_error: 0.0438

# %%
train_history = pd.DataFrame(history.history)
# display(train_history)
print(len(train_history))

config["training"]["num_epoch"] = len(train_history)

fig = plt.figure(figsize=(25, 7), dpi=80)
plt.plot(range(1,config["training"]["num_epoch"]+1), train_history['loss'], label = "train loss")
plt.plot(range(1,config["training"]["num_epoch"]+1), train_history['val_loss'], label = 'validation loss')
plt.legend()
# train_history.plot(figsize=(20,7))
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xticks(range(10,config["training"]["num_epoch"]+1,10), rotation='vertical') 
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
plt.show()

fig = plt.figure(figsize=(25, 7), dpi=80)
plt.plot(range(1,config["training"]["num_epoch"]+1), train_history['mean_absolute_error'])
plt.plot(range(1,config["training"]["num_epoch"]+1), train_history['val_mean_absolute_error'])
# train_history.plot(figsize=(20,7))
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xticks(range(10,config["training"]["num_epoch"]+1,10), rotation='vertical') 
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
plt.show()
# Out:
# 181

# %% [markdown]
# Analysis

# %%
# Kernel Ridge Regression
from sklearn.kernel_ridge import KernelRidge
def calculate_krr(_data, _scaled):
    krr = KernelRidge(alpha=0.1, kernel='rbf') # why is rbf been used here? and what does the alpha control
    # Train the model on the training data
    krr.fit(_data['xtrain'][:, -1, :], _data['ytrain'])
    # Make predictions on the test data
    pred_krr = krr.predict(_data['xtest'][:, -1, :])
    if _scaled:
        pred_krr = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(pred_krr, axis=0)))
    return pred_krr
# Simple Moving Average
def calculate_ma(_data, _scaled):
    # calcualte the price using a simple moving average
    pred_ma = np.mean(_data["xtest"], axis = 1)
    pred_ma = pred_ma[:, 0] # take only the adjclose price out
    if _scaled:
        pred_ma = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(pred_ma, axis=0)))
    return pred_ma
# Exponentila Moving Average
def calculate_ema(_data, _scaled, _window):
    # calculate the price using exponential moving average
    pred_ema = _data["xtest"][:, :, 0] # only take the 
    # pred_EMA = np.squeeze(config["data"]["scaler"].inverse_transform(pred_EMA))
    weights = np.exp(np.linspace(-1, 0, _window))
    weights /= weights.sum()
    pred_ema = pred_ema@weights
    if _scaled:
        pred_ema = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(pred_ema, axis=0)))
    return pred_ema

config['data']['scale']
# copmare each network against each other
predictions = {}
y = data["ytest"]

# if scaled
if config['data']['scale']:
    y = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(y, axis=0)))
# needs to be updated

predictions["net"] = model.predict(data["xtest"])
# if the data is scaled
# print(model.predict(data["xtest"]))
if config['data']['scale']:
    predictions["net"] = np.squeeze(config["data"]["scaler"].inverse_transform(model.predict(data["xtest"])))
# needs to be updated

if 0:
    # add the other methods to compare against
    predictions["krr"] = calculate_krr(data, config['data']['scale'])
    predictions["ma"] = calculate_ma(data, config['data']['scale'])
    predictions["ema"] = calculate_ema(data, config['data']['scale'], config['nn']['window'])



# plot_predictions(data["testDates"], y, predictions, section, comb['dataset'])
# calc_stats(y, predictions, comb["networks"])
# store the predictions made
# break
# Out:
# 2023-03-14 12:31:16.542978: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:31:16.612515: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-14 12:31:16.692579: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 8/8 [==============================] - 1s 19ms/step
# 8/8 [==============================] - 0s 10ms/step

# %%
import matplotlib.pyplot as plt
import pickle
from datetime import datetime

# MAKE A FUNCTION FOR EACH COMPARISON TOOL
# Mean Squared Error
calc_mse = lambda y_true, y_pred: np.mean((y_true-y_pred)**2)
# Root Mean Squared Error
calc_rmse = lambda y_true, y_pred: np.sqrt(np.mean((y_true-y_pred)**2))
# Mean Absolute Error
calc_mae = lambda y_true, y_pred: np.mean(np.abs((y_true-y_pred)))
# Mean Absolute Percentage Error
calc_mape = lambda y_true, y_pred: np.mean(np.abs((y_true-y_pred) / y_true))*100
# Directional accuracy
calc_da = lambda y_true, y_pred: np.mean([(y_true[i+1]-y_true[i])*(y_pred[i+1]-y_pred[i]) >= 0 for i in range(len(y_true)-1)])
# Coefficient of determination R²
calc_cod = lambda y_true, y_pred: 1 - (sum((y_true - y_pred)**2) / sum((y_true - np.mean(y_true))**2))
# calculate the statistics
def calc_stats(_actual, _predictions, _nets = []):
    d = {}
    for net, pred in enumerate(_predictions):
        prediction = _predictions[pred]
        key = pred
        if pred in _nets:
            key = "net" + str(net)
            print(key, "-", pred) # show the network config
        # go throught the selected methods and get results
        d[key] = [func(_actual[:], prediction[:]) for func in (calc_mse, calc_rmse, calc_mae, calc_mape, calc_da, calc_cod)]
    # create a dataframe from the information
    df = pd.DataFrame(d)
    df.index = ['MSE', 'RMSE', 'MAE', 'MAPE', 'DA', 'R²'] # set the index of the dataframe
    display(df) # display the dataframe
    return df

# replace all [:] with [-n:] for the last n bits of data
# to plot results
def plot_predictions(_dates, _y, _predictions, _dataset, _section = 'Test', _highlight = []):
    # plot the results
    fig = plt.figure(figsize=(25, 7), dpi=80)
    # plot the true values
    plt.plot(_dates[:], _y[:], "*-", label = "True Values")
    # plot all the predictions
    for idx, pred in enumerate(_predictions):
        if idx in _highlight:
            alpha = 0.9
        elif not _highlight: # if the list is empty
            alpha = 0.4
        else:
            alpha = 0.1
        plt.plot(_dates[:], _predictions[pred][:], "*-", label = pred, alpha = alpha)
    plt.legend() # show the labels
    plt.title(f"{len(_y)} days of {_section.upper()} data {_dataset}")
    plt.xlabel("Date")
    plt.ylabel("Closing price")
    # plt.xticks(_dates, rotation = "vertical")
    plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
    plt.show()

# generate the file name to save all of the results
file_name = datetime.now()
file_name = str(file_name).replace(':', '_').split('.')
file_name = 'training ' + file_name[0] + '.pkl'


y = data["ytest"]
    
# if scaled
if config['data']['scale']:
    y = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(y, axis=0)))

plot_predictions(data["testDates"], y, predictions, config['data']['ticker'], "Test", [0])
stats = calc_stats(y, predictions)

stats.T.plot.bar(subplots=True, figsize=(14,7), layout=(2,3), legend=False)

    # save data sets with all the loading options
    # with open(f"results/{file_name.replace('training', str(comb['dataset']))}", 'wb') as f:
    #     pickle.dump([comb['dataset'], comb["predictions"], data], f)
    
    # store the predictions made
    # break
# Out:
#              net
# MSE   202.606431
# RMSE   14.233989
# MAE    11.557026
# MAPE    5.242402
# DA      0.500000
# R²      0.932163
# array([[<AxesSubplot: title={'center': 'MSE'}>,
#         <AxesSubplot: title={'center': 'RMSE'}>,
#         <AxesSubplot: title={'center': 'MAE'}>],
#        [<AxesSubplot: title={'center': 'MAPE'}>,
#         <AxesSubplot: title={'center': 'DA'}>,
#         <AxesSubplot: title={'center': 'R²'}>]], dtype=object)

# %% [markdown]
# Results

# %%
# for the training
pred_ytrain = model.predict(data["xtrain"])
ytrain = data["ytrain"]
# scaler = config["data"]["scaler"]
pred_ytrain = np.squeeze(config["data"]["scaler"].inverse_transform(pred_ytrain))
ytrain = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(ytrain, axis=0)))


# for the training
pred_yval = model.predict(data["xval"])
yval = data["yval"]
# scaler = config["data"]["scaler"]
pred_yval = np.squeeze(config["data"]["scaler"].inverse_transform(pred_yval))
yval = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(yval, axis=0)))


# for the training
pred_ytest = model.predict(data["xtest"])
ytest = data["ytest"]
# scaler = config["data"]["scaler"]
pred_ytest = np.squeeze(config["data"]["scaler"].inverse_transform(pred_ytest))
ytest = np.squeeze(config["data"]["scaler"].inverse_transform(np.expand_dims(ytest, axis=0)))


# ALL 3 TOGETHER
# plot the results
fig= plt.figure(figsize=(25, 7), dpi=80)
# for the training
plt.plot(data["trainDates"],ytrain) # train data
plt.plot(data["trainDates"], pred_ytrain)
plt.plot(data["valDates"], yval) # val data
plt.plot(data["valDates"], pred_yval)
plt.plot(data["testDates"], ytest) # test data
plt.plot(data["testDates"], pred_ytest)
plt.title(f"All of the data from {config['data']['ticker']}")
plt.xlabel("Dates")
plt.ylabel("Closing price")
plt.legend("Actual Training Price,Predicted Training Price,Actual Validation Price,Predicted Validatoin Price,Actual Testing Price,Predicted Testing Price".split(","))
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
plt.show()


fig= plt.figure(figsize=(25, 7), dpi=80)
# for the training
plt.plot(data["trainDates"],ytrain) # train data
plt.plot(data["valDates"], yval) # val data
plt.plot(data["testDates"], ytest) # test data
plt.title(f"9 years of data from {config['data']['ticker']}")
plt.xlabel("Dates")
plt.ylabel("Closing price")
plt.legend("Training dataset,Validation dataset,Testing dataset".split(","))
plt.grid(which="major", color='k', linestyle=':', linewidth=1, alpha = 0.2)
plt.show()
# Out:
# 57/57 [==============================] - 1s 10ms/step
# 7/7 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 9ms/step
